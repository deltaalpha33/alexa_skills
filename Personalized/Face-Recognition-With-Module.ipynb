# %% [markdown]
# # Functions and Requirements

# %%
# %matplotlib notebook
from face_label import face_labeling_personalized as fl

# %% [markdown]
# ### Load Vectors

# %%
DB = fl.loadDBnp("vectors")
# Out:
# vectors\Daschel
# vectors\Dimitris
# vectors\Henry
# vectors\Lucia
# vectors\Manu
# vectors\Ryan
# vectors\Victor

# %% [markdown]
# ## Take and Label an Image

# %%
fl.label_faces_text(fl.take_picture(),DB)
# Out:
# 0.315731118619
# Daschel 0.315731118619
# 'I see Daschel'

# %%
fl.label_faces(fl.take_picture(),DB)
# Out:
# <img src="data:image/png;base64,..." width="640">
# 0.348594322024
# Daschel 0.348594322024

# %% [markdown]
# ### Take a picture
# Save its vector and add it to DB

# %%
name = "ERROR"

fl.addImgToDB(DB,fl.take_picture(),name)
fl.saveDBnp("vectors",DB)
