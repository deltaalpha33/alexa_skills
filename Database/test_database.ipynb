# %%
from Entity_Database import Entity_Database

# %%
x = Entity_Database(rss_links=["http://feeds.reuters.com/Reuters/domesticNews"])

# %%
x.entities
# Out:
# {'http://feeds.reuters.com/~r/Reuters/domesticNews/~3/4uZfGee4Ufw/us-ford-safety-idUSKBN1AD052': Tree('S', [Tree('NE', [('U.S.', 'NNP')]), ('upgrades', 'JJ'), ('probe', 'NN'), ('into', 'IN'), ('1.33', 'CD'), ('million', 'CD'), ('Ford', 'NNP'), ('Explorers', 'NNP'), ('over', 'IN'), ('exhaust', 'JJ'), ('odors', 'NNS'), ('FILE', 'NNP'), ('PHOTO', 'NNP'), (':', ':'), ('The', 'DT'), ('2016', 'CD'), ('Ford', 'NNP'), ('Explorer', 'NNP'), ('is', 'VBZ'), ('shown', 'VBN'), ('during', 'IN'), ('the', 'DT'), ('model', 'NN'), ("'s", 'POS'), ('world', 'NN'), ('debut', 'NN'), ('at', 'IN'), ('the', 'DT'), Tree('NE', [('Los', 'NNP'), ('Angeles', 'NNP'), ('Auto', 'NNP'), ('Show', 'NNP')]), ('in', 'IN'), Tree('NE', [('Los', 'NNP'), ('Angeles', 'NNP')]), (',', ','), Tree('NE', [('California', 'NNP')]), ('November', 'NNP'), ('19', 'CD'), (',', ','), ('2014.Lucy', 'CD'), Tree('NE', [('Nicholson', 'NNP')]), Tree('NE', [('WASHINGTON', 'NNP')]), ('(', '('), ('Reuters', 'NNP'), (')', ')'), ('-', ':'), ('The', 
# ...

# %%
x.documents
# Out:
# {'http://feeds.reuters.com/~r/Reuters/domesticNews/~3/4uZfGee4Ufw/us-ford-safety-idUSKBN1AD052': 'U.S. upgrades probe into 1.33 million Ford Explorers over exhaust odors\n\nFILE PHOTO: The 2016 Ford Explorer is shown during the model\'s world debut at the Los Angeles Auto Show in Los Angeles, California November 19, 2014.Lucy Nicholson\n\nWASHINGTON (Reuters) - The U.S. National Highway Traffic Safety Administration is upgrading and expanding a probe into 1.33 million Ford Explorer SUVs over reports of exhaust odors in vehicle compartments and exposure to carbon monoxide that may be linked to crashes and injuries.\n\nThe auto safety agency said in a statement on Thursday it was aware of more than 2,700 complaints and three crashes that may be linked to exposure to carbon monoxide and 41 injuries among police and civilian vehicles in the probe covering 2011-2017 model year Ford Explorer sport utility vehicles.\n\nFord has issued multiple technical service bulletins related to the exha
# ...

# %%
x.search_engine.query("Reuters")
# Out:
# [('http://feeds.reuters.com/~r/Reuters/domesticNews/~3/Yg8I3h2K73E/us-fiatchrysler-emissions-idUSKBN1AD1TI',
#   0.012886645295977925),
#  ('http://feeds.reuters.com/~r/Reuters/domesticNews/~3/AYCkSYb7OIk/us-usa-military-transgender-exclusive-idUSKBN1AC2FN',
#   0.0071425100831369187),
#  ('http://feeds.reuters.com/~r/Reuters/domesticNews/~3/HBqeg1IyyME/us-usa-trump-gangs-idUSKBN1AD0GK',
#   0.005121853071829198),
#  ('http://feeds.reuters.com/~r/Reuters/domesticNews/~3/UH1taGDasjM/us-ohio-ride-dutch-idUSKBN1AC305',
#   0.0045665287656238415),
#  ('http://feeds.reuters.com/~r/Reuters/domesticNews/~3/_vxdRNsBbcw/us-texas-execution-idUSKBN1AC1J3',
#   0.0032243122633233475),
#  ('http://feeds.reuters.com/~r/Reuters/domesticNews/~3/igI216q7wuk/us-kansas-governor-idUSKBN1AD06U',
#   0.0031886822664130583),
#  ('http://feeds.reuters.com/~r/Reuters/domesticNews/~3/JqxcKxUQjTU/us-un-corruption-idUSKBN1AC3AN',
#   0.0026683047217762614),
# ...

# %%
x.search_engine.get('http://feeds.reuters.com/~r/Reuters/domesticNews/~3/igI216q7wuk/us-kansas-governor-idUSKBN1AD06U',
  0.0031886822664130583)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-be935d5c16c8> in <module>()
#       1 x.search_engine.get('http://feeds.reuters.com/~r/Reuters/domesticNews/~3/igI216q7wuk/us-kansas-governor-idUSKBN1AD06U',
# ----> 2   0.0031886822664130583)
#
# TypeError: get() takes 2 positional arguments but 3 were given
